# %%
import os
import sys

from typing import List

from alibabacloud_devops20210625.client import Client as devops20210625Client
from alibabacloud_tea_openapi import models as open_api_models
from alibabacloud_tea_util import models as util_models
from alibabacloud_tea_util.client import Client as UtilClient
from alibabacloud_devops20210625 import models as devops_20210625_models

ALIBABA_CLOUD_ACCESS_KEY_ID = os.environ.get(
    "ALIBABA_CLOUD_ACCESS_KEY_ID", "请配置：ALIBABA_CLOUD_ACCESS_KEY_ID"
)  # 也可以直接把ACCESS_KEY_ID放在这里

ALIBABA_CLOUD_ACCESS_KEY_SECRET = os.environ.get(
    "ALIBABA_CLOUD_ACCESS_KEY_SECRET", "请配置：ALIBABA_CLOUD_ACCESS_KEY_SECRET"
)  # 也可以直接把ACCESS_KEY_SECRET放在这里

# print(ALIBABA_CLOUD_ACCESS_KEY_ID, ALIBABA_CLOUD_ACCESS_KEY_SECRET)

# print(os.environ['ALIBABA_CLOUD_ACCESS_KEY_ID'], os.environ['ALIBABA_CLOUD_ACCESS_KEY_SECRET'])
config = open_api_models.Config(
            access_key_id=ALIBABA_CLOUD_ACCESS_KEY_ID,
            access_key_secret=ALIBABA_CLOUD_ACCESS_KEY_SECRET
        )
# Endpoint 请参考 https://api.aliyun.com/product/devops
config.endpoint = f'devops.cn-hangzhou.aliyuncs.com'
client = devops20210625Client(config)

# %%
# 项目列表

import json
import pandas as pd

runtime = util_models.RuntimeOptions()
headers = {}
organization_id = "6189f099041d450d2c253abc"
project_id = "a41d2acc436b9755f11b79d3d4"

# print(client.list_organizations(request=devops_20210625_models.ListOrganizationsRequest()).body)

req = devops_20210625_models.ListProjectWorkitemTypesRequest(
    space_type="Project", category="req"
)
res = client.list_project_workitem_types_with_options(
    organization_id=organization_id,
    project_id=project_id,
    headers=headers,
    runtime=runtime,
    request=req,
)
# print(res.body)

req_id = "1a787d02dbffcf9bbe93e73631"

req = devops_20210625_models.ListWorkItemAllFieldsRequest(
    space_type="Project", space_identifier=project_id, workitem_type_identifier=req_id
)
res = client.list_work_item_all_fields_with_options(
    organization_id=organization_id, headers=headers, runtime=runtime, request=req
)

# print(res.body)
# all_fields=json.loads(res.body)

fields_df = pd.DataFrame(res.body.to_map()["fields"])
fields_df.describe()

start_date = "2024-04-01"
end_date = "2024-06-30"

work_item_condition = {
    "conditionGroups": [
        [
            {
                "fieldIdentifier": "status",
                "operator": "CONTAINS",
                "value": ["100014"],
                "toValue": None,
                "className": "status",
                "format": "list",
            },
            {
                "fieldIdentifier": "finishTime",
                "operator": "BETWEEN",
                "value": [f"{start_date} 00:00:00"],
                "toValue": f"{end_date} 23:59:59",
                "className": "date",
                "format": "input",
            },
            {
                "fieldIdentifier": "tag",
                "operator": "CONTAINS",
                "value": ["02c574f4854f04fde8339ba2b1", "a6b2221931325308e07f88220f"],
                "toValue": None,
                "className": "tag",
                "format": "multiList",
            },
        ]
    ]
}
work_item_condition = json.dumps(work_item_condition)
# '{"conditionGroups":[[{"fieldIdentifier":"status","operator":"CONTAINS","value":["63798bd5f6855ea51abcd1b0d6"],"toValue":null,"className":"status","format":"list"},{"fieldIdentifier":"workitemType","operator":"CONTAINS","value":["1a787d02dbffcf9bbe93e73631"],"toValue":null,"className":"workitemType","format":"list"}]]}'
req = devops_20210625_models.ListWorkitemsRequest(
    space_type="Project",
    category="Req",
    conditions=work_item_condition,
    max_results=200,
    search_type="LIST",
    space_identifier=project_id,
)
res = client.list_workitems(
    organization_id=organization_id,
    #    headers=headers,
    #    runtime=runtime,
    request=req,
)

items_array = res.body.to_map()["workitems"]


# 将这段代码转成小方法，参数：workitem_id,organization_id
def get_work_item_info(workitem_id, organization_id):
    work_item = client.get_work_item_info(
        workitem_id=workitem_id, organization_id=organization_id
    )
    return work_item.body.to_map()["workitem"]


# 循环items_array，使用每个workitem的id，调用get_work_item_info方法，获取workitem的详细信息，并将结果保存到一个列表中
work_item_info_list = []
for item in items_array:
    work_item_info_list.append(get_work_item_info(item["identifier"], organization_id))

# %%
fields_dict = {}
for index, row in fields_df.iterrows():
    row_data = row.to_dict()  # Convert the row to a dictionary
    fields_dict[row_data['identifier']] = row_data['name']

fields_dict
# Out:
# {'subject': '标题',
#  'description': '描述',
#  'parent': '父项ID',
#  'parentWhetherExist': '父项是否存在',
#  'parentSubject': '父项标题',
#  'workitemType': '工作项类型',
#  'status': '状态',
#  'assignedTo': '负责人',
#  'e4c05dae33ce16b6e3ed4f65ea': '测试负责人',
#  'priority': '优先级',
#  'space': '归属项目',
#  'sprint': '迭代',
#  'ak.issue.member': '参与者',
#  'workitem.tracker': '抄送',
#  'tag': '标签',
#  '79': '计划开始时间',
#  '80': '计划完成时间',
#  'relatedSpace': '共享项目',
#  'a6f2cf7e6c69e5006ac4cd5146': '变更后完成时间',
#  'version': '版本',
#  '2000c2aad751b7871d0895d7d4': '需求评审不通过原因',
#  'edd9f7d98179e7f47fae41b135': 'UI评审不通过原因',
#  '51ec6c83a2b9c10d5b437ab616': '提测打回原因',
#  '8159aca815ebf0b25a9e4d0d67': '提测打回责任人',
#  'a08493245a9cf9fe250677233e': '产品验收不通过原因',
#  '2c322e0439231d088adafdf7c2': 'UI验收不通过原因',
#  '1cf9f1e546618af480f9cec18c': '需求延期类型',
#  'b37f146595fd4734d69675690c': '需求延期原因',
#  '16b58fbf0eb1556eaacffcd6d5': '延期责任人',
#  'fba0a046ffed2f9c5224db5493': '归属业务'}

# %%
fields_dict

# 获取工作项的活动记录
def get_work_item_activities(workitem):
    activities=client.get_work_item_activity(organization_id=organization_id, workitem_id=workitem['identifier']).body
    activities_dict={}
    for act in activities.to_map()['activities']:
        if act['eventType'] == 'workitem.transitioned':
            activity_name = act['newValue'][0]['displayValue']
            if activity_name in activities_dict:
                new_value=pd.to_datetime(act['eventTime'], unit='ms').strftime('%Y-%m-%d %H:%M:%S')
                old_value=activities_dict[activity_name]
                if new_value > old_value:
                    activities_dict[activity_name]=new_value
            else:
                activities_dict[activity_name]=pd.to_datetime(act['eventTime'], unit='ms').strftime('%Y-%m-%d %H:%M:%S')
    print(activities_dict)
    workitem['activities_dict']=activities_dict
    return workitem

# 遍历所有项目，获取每个项目的活动记录
for work_item in work_item_info_list:
    workitems=get_work_item_activities(work_item)

for item in work_item_info_list:
    custom_fields_dict = {}
    for custom_field in item['customFields']:
        fieldIdentifier=custom_field['fieldIdentifier']
        if fieldIdentifier in fields_dict:
            custom_fields_dict[fields_dict[fieldIdentifier]] = custom_field['value']
        else:
            custom_fields_dict[fieldIdentifier] = custom_field['value']
    print(custom_fields_dict)
    get_work_item_activities(workitem=item)
    item['custom_fields_dict'] = custom_fields_dict
# Out:
# {'已完成': '2024-06-06 02:03:14', '待发布': '2024-06-06 02:03:11', '待测试': '2024-06-06 02:03:01', '开发中': '2024-06-05 10:31:26', '需求&UI评审完成': '2024-06-05 10:31:17', '待需求评审': '2024-06-05 07:40:28', '需求设计中': '2024-06-05 07:40:24'}
# {'已完成': '2024-06-07 01:30:43', '待产品&UI验收': '2024-06-06 10:08:27', '测试中': '2024-06-06 10:07:43', '待测试': '2024-06-06 10:07:34', '开发中': '2024-06-05 10:31:15', '技术评审完成': '2024-06-04 08:50:32', '技术方案设计中': '2024-06-04 07:14:24', '需求&UI评审完成': '2024-06-04 07:14:21', '待需求评审': '2024-06-04 07:13:07', '待需求预审': '2024-06-04 07:12:47', '需求设计中': '2024-06-04 07:12:45'}
# {'已完成': '2024-06-07 02:07:06', '待发布': '2024-06-07 02:06:58', '待测试': '2024-06-07 02:06:45', '开发中': '2024-06-05 02:08:44', '技术评审完成': '2024-06-05 02:08:39', '技术方案设计中': '2024-06-03 11:02:45', '需求&UI评审完成': '2024-06-03 11:02:42'}
# {'已完成': '2024-06-07 01:23:14', '待测试': '2024-06-05 10:32:05', '开发中': '2024-05-30 01:54:19', '需求&UI评审完成': '2024-05-30 01:53:59'}
# {'已完成': '2024-06-05 10:49:19', '待测试': '2024-06-05 10:49:14', '开发中': '2024-06-05 10:49:09', '技术评审完成': '2024-06-05 10:48:59', '技术方案设计中': '2024-05-30 10:35:00', '需求&UI评审完成': '2024-05-30 10:34:54', '待需求评审': '2024-05-30 10:34:45', '需求设计中': '2024-05-29 02:55:23'}
# {'已完成': '2024-06-05 10:31:04', '待发布': '2024-06-05 02:22:45', '待产品&UI验收': '2024-06-05 02:01:14', '测试中': '2024-06-04 01:39:56', '待测试': '2024-06-03 07:13:06', '开发中': '2024-05-30 05:51:10', '技术评审完成': '2024-05-30 05:51:06', '技术方案设计中': '2024-05-30 01:43:44', '需求&UI评审完成': '2024-05-29 06:46:32', '待需求预审': '2024-05-29 02:08:53', '需求设计中': '2024-05-29 02:08:49'}
# {'已完成': '2024-06-03 02:12:20', '待发布': '2024-06-03 02:12:18', '待测试': '2024-06-03 02:12:11', '开发中': '2024-06-03 02:12:06', '技术评审完成': '2024-06-03 02:12:01', '技术方案设计中': '2024-05-28 01:59:33', '需求&UI评审完成': '2024-05-28 01:59:07', '需求设计中': '2024-05-28 01:58:58'}
# {'已完成': '2024-05-28 02:11:51', '待测试': '2024-05-28 02:11:48', '开发中': '2024-05-28 02:11:40', '需求&UI评审完成': '2024-05-28 02:10:19', '待需求评审': '2024-05-22 02:27:32', '待需求预审': '2024-05-22 02:27:29', '需求设计中': '2024-05-22 02:27:26'}
# {'已完成': '2024-05-24 11:08:09', '待产品&UI验收': '2024-05-24 11:07:34', '测试中': '2024-05-24 11:07:17', '待测试': '2024-05-24 11:07:08', '开发中': '2024-05-20 10:51:29', '技术评审完成': '2024-05-20 06:31:08', '技术方案设计中': '2024-05-20 06:31:01', '需求&UI评审完成': '2024-05-20 06:30:57', '待需求评审': '2024-05-17 09:29:37', '需求设计中': '2024-05-17 09:29:33'}
# {'已完成': '2024-05-28 07:43:14', '待测试': '2024-05-28 07:43:11', '开发中': '2024-05-28 02:11:20', '需求&UI评审完成': '2024-05-28 02:07:41', '待需求评审': '2024-05-16 09:30:16', '需求设计中': '2024-05-16 09:30:15', '待需求预审': '2024-05-16 09:30:12'}
# {'已完成': '2024-05-16 07:08:37', '待测试': '2024-05-16 07:08:34', '开发中': '2024-05-16 07:08:25', '需求&UI评审完成': '2024-05-16 07:08:04', '待需求评审': '2024-05-16 07:06:46', '待需求预审': '2024-05-16 07:06:44', '需求设计中': '2024-05-16 07:06:43'}
# {'已完成': '2024-05-20 10:05:45', '待产品&UI验收': '2024-05-20 10:05:00', '测试中': '2024-05-17 08:06:23', '待测试': '2024-05-17 08:06:13', '开发中': '2024-05-15 10:59:12', '需求&UI评审完成': '2024-05-15 10:58:55', '待需求评审': '2024-05-14 09:09:12', '待需求预审': '2024-05-14 09:05:04', '需求设计中': '2024-05-14 09:05:02'}
# {'已完成': '2024-06-05 08:55:35', '待产品&UI验收': '2024-06-04 11:08:13', '待测试': '2024-06-04 11:08:07', '开发中': '2024-05-29 11:15:11', '需求&UI评审完成': '2024-05-29 11:14:53', '需求评审通过待设计': '2024-05-24 09:29:54', '待需求评审': '2024-05-24 08:56:52', '待需求预审': '2024-05-14 06:49:08', '需求设计中': '2024-05-14 06:49:06'}
# {'已完成': '2024-05-22 03:11:50', '待产品&UI验收': '2024-05-21 05:43:30', '测试中': '2024-05-20 09:36:43', '待测试': '2024-05-20 09:36:28', '开发中': '2024-05-15 09:19:08', '技术评审完成': '2024-05-15 09:19:03', '技术方案设计中': '2024-05-14 06:55:40', '需求&UI评审完成': '2024-05-14 06:55:36', '待需求评审': '2024-05-14 06:05:45', '待需求预审': '2024-05-14 02:59:01', '需求设计中': '2024-05-14 02:58:58'}
# {'已完成': '2024-04-28 10:12:06', '待产品&UI验收': '2024-04-28 10:11:26', '测试中': '2024-04-28 02:01:42', '待测试': '2024-04-26 11:01:58', '开发中': '2024-04-26 11:01:46', '需求&UI评审完成': '2024-04-26 11:01:28', '待需求评审': '2024-04-25 10:50:13', '待需求预审': '2024-04-25 10:50:10', '需求设计中': '2024-04-25 10:50:08'}
# {'已完成': '2024-05-10 02:11:11', '待测试': '2024-05-10 02:11:07', '开发中': '2024-04-30 02:05:18', '需求&UI评审完成': '2024-04-26 02:06:28', '待需求评审': '2024-04-25 02:12:57', '需求设计中': '2024-04-25 02:12:54'}
# {'已完成': '2024-04-28 08:20:28', '待产品&UI验收': '2024-04-28 02:16:07', '测试中': '2024-04-25 10:30:51', '待测试': '2024-04-25 10:30:37', '开发中': '2024-04-25 10:30:27', '需求&UI评审完成': '2024-04-25 03:44:05', '待需求评审': '2024-04-24 11:18:42', '待需求预审': '2024-04-24 11:18:38', '需求设计中': '2024-04-24 11:18:32'}
# {'已完成': '2024-06-03 11:03:13', '待产品&UI验收': '2024-06-03 01:56:22', '测试中': '2024-05-31 09:05:20', '待测试': '2024-05-31 02:49:38', '开发中': '2024-05-23 02:02:51', '技术评审完成': '2024-05-22 09:51:36', '技术方案设计中': '2024-05-22 05:59:34', '需求&UI评审完成': '2024-05-21 02:17:20', '待需求评审': '2024-04-24 03:50:14', '待需求预审': '2024-04-24 03:50:06', '需求设计中': '2024-04-24 03:50:04'}
# {'已完成': '2024-05-27 10:43:18', '待发布': '2024-05-27 10:37:49', '待产品&UI验收': '2024-05-27 10:35:33', '测试中': '2024-05-27 10:35:25', '待测试': '2024-05-20 11:12:47', '开发中': '2024-05-10 00:37:52', '技术评审完成': '2024-05-10 00:37:50', '技术方案设计中': '2024-04-26 09:15:21', '需求&UI评审完成': '2024-04-26 02:19:48', '待需求评审': '2024-04-24 11:18:45', '待需求预审': '2024-04-24 11:18:35', '需求设计中': '2024-04-22 10:55:08'}
# {'已完成': '2024-04-28 12:29:32', '待产品&UI验收': '2024-04-28 02:16:01', '测试中': '2024-04-28 02:13:40', '待测试': '2024-04-28 02:13:30', '开发中': '2024-04-26 02:20:17', '需求&UI评审完成': '2024-04-24 08:40:18', '待需求预审': '2024-04-22 03:03:51', '需求设计中': '2024-04-22 03:03:48'}
# {'已完成': '2024-04-19 03:57:17', '待测试': '2024-04-19 03:57:08', '开发中': '2024-04-19 03:56:37', '需求&UI评审完成': '2024-04-19 03:55:03', '待需求评审': '2024-04-19 03:45:25', '待需求预审': '2024-04-19 03:45:19', '需求设计中': '2024-04-19 03:45:16'}
# {'已完成': '2024-04-19 08:44:19', '待产品&UI验收': '2024-04-19 08:00:10', '测试中': '2024-04-19 07:35:42', '待测试': '2024-04-19 07:35:33', '开发中': '2024-04-18 09:18:56', '需求&UI评审完成': '2024-04-18 09:18:54', '待需求评审': '2024-04-18 05:42:49', '需求设计中': '2024-04-18 05:42:45'}
# {'已完成': '2024-05-15 11:04:58', '待发布': '2024-05-13 03:24:36', '待测试': '2024-05-11 06:51:35', '开发中': '2024-04-28 09:36:53', '技术评审完成': '2024-04-28 09:36:47', '技术方案设计中': '2024-04-23 02:49:22', '需求&UI评审完成': '2024-04-22 10:02:02', '待需求预审': '2024-04-18 02:15:00', '需求设计中': '2024-04-18 02:14:58'}
# {'已完成': '2024-04-23 10:31:30', '待发布': '2024-04-23 05:34:37', '待测试': '2024-04-22 01:59:38', '开发中': '2024-04-18 01:56:05', '技术评审完成': '2024-04-18 01:56:01', '技术方案设计中': '2024-04-15 02:09:52', '需求&UI评审完成': '2024-04-15 02:09:48'}
# {'已完成': '2024-04-15 10:50:59', '待产品&UI验收': '2024-04-15 08:27:42', '测试中': '2024-04-15 08:08:03', '待测试': '2024-04-15 02:15:09', '开发中': '2024-04-12 03:10:17', '需求&UI评审完成': '2024-04-11 08:07:58', '待需求评审': '2024-04-11 06:13:24', '需求设计中': '2024-04-11 06:13:21'}
# {'已完成': '2024-05-28 09:58:01', '待发布': '2024-05-27 03:00:46', '待测试': '2024-05-20 01:53:38', '开发中': '2024-05-06 02:49:33', '技术评审完成': '2024-05-06 02:49:03', '技术方案设计中': '2024-04-17 02:04:15', '需求&UI评审完成': '2024-04-17 02:04:11', '待需求评审': '2024-04-10 11:49:57', '待需求预审': '2024-04-10 11:49:54', '需求设计中': '2024-04-10 11:49:53'}
# {'已完成': '2024-05-07 02:52:59', '待测试': '2024-05-07 02:52:56', '开发中': '2024-04-28 10:59:47', '需求&UI评审完成': '2024-04-24 02:05:15', 'UI交互设计中': '2024-04-22 07:53:23', '需求评审通过待设计': '2024-04-19 02:50:40', '待需求评审': '2024-04-09 10:44:18', '待需求预审': '2024-04-09 10:44:14', '需求设计中': '2024-04-09 10:44:12'}
# {'已完成': '2024-04-12 10:50:04', '待产品&UI验收': '2024-04-12 08:03:53', '待测试': '2024-04-12 08:03:25', '开发中': '2024-04-11 03:33:49', '需求&UI评审完成': '2024-04-10 10:57:02', '待需求评审': '2024-04-09 10:42:17', '待需求预审': '2024-04-09 10:42:09', '需求设计中': '2024-04-09 10:42:06'}
# {'已完成': '2024-04-10 10:11:11', '待产品&UI验收': '2024-04-10 10:11:08', '测试中': '2024-04-10 09:03:26', '待测试': '2024-04-10 09:03:04', '开发中': '2024-04-10 07:47:53', '需求&UI评审完成': '2024-04-10 02:02:13', '待需求评审': '2024-04-09 10:23:09', '需求设计中': '2024-04-09 10:23:06'}
# {'已完成': '2024-04-09 03:49:49', '待测试': '2024-04-09 03:49:44', '开发中': '2024-04-09 02:51:45', '需求&UI评审完成': '2024-04-09 02:51:34', '需求设计中': '2024-04-09 02:40:40'}
# {'已完成': '2024-04-12 10:49:46', '待产品&UI验收': '2024-04-12 08:03:46', '待测试': '2024-04-12 08:03:33', '开发中': '2024-04-11 08:52:57', '需求&UI评审完成': '2024-04-10 10:56:17', '待需求评审': '2024-04-08 06:46:25', '待需求预审': '2024-04-08 06:46:18', '需求设计中': '2024-04-08 06:46:16'}
# {'已完成': '2024-04-18 10:56:06', '待产品&UI验收': '2024-04-18 08:04:23', '测试中': '2024-04-18 02:30:52', '待测试': '2024-04-12 09:05:26', '开发中': '2024-04-11 08:55:55', '需求&UI评审完成': '2024-04-10 10:56:35', '待需求评审': '2024-04-08 06:43:18', '待需求预审': '2024-04-08 06:43:03', '需求设计中': '2024-04-08 06:43:00'}
# {'已完成': '2024-04-07 08:05:13', '待产品&UI验收': '2024-04-07 08:04:59', '测试中': '2024-04-07 08:04:45', '待测试': '2024-04-07 08:04:36', '开发中': '2024-04-01 11:07:33', '技术评审完成': '2024-04-01 11:07:31', '技术方案设计中': '2024-04-01 11:07:28', '需求&UI评审完成': '2024-03-29 02:04:37', '待需求评审': '2024-03-28 03:16:09', '待需求预审': '2024-03-28 03:16:06', '需求设计中': '2024-03-28 03:16:03'}
# {'已完成': '2024-04-02 07:28:20', '待测试': '2024-04-02 02:06:11', '开发中': '2024-04-01 02:12:22', '需求&UI评审完成': '2024-03-29 02:05:45', '待需求预审': '2024-03-21 07:48:12', '需求设计中': '2024-03-21 05:58:44'}
# {'已完成': '2024-04-09 07:09:44', '待发布': '2024-04-09 07:09:05', '待产品&UI验收': '2024-04-09 06:57:36', '测试中': '2024-04-08 02:01:34', '待测试': '2024-04-08 02:01:27', '开发中': '2024-03-29 08:46:48', '需求&UI评审完成': '2024-03-25 02:12:59', '待需求预审': '2024-03-21 09:56:53', '需求设计中': '2024-03-21 03:28:44'}
# {'已完成': '2024-04-23 09:49:57', '待产品&UI验收': '2024-04-23 05:50:53', '测试中': '2024-04-16 09:20:11', '待测试': '2024-04-16 09:20:08', '开发中': '2024-04-09 08:17:38', '需求&UI评审完成': '2024-04-07 08:22:27', '待需求评审': '2024-03-29 05:44:24', '待需求预审': '2024-03-29 05:44:18', '需求设计中': '2024-03-15 07:27:21'}
# {'已完成': '2024-04-11 11:10:46', '待发布': '2024-04-10 11:50:56', '待产品&UI验收': '2024-04-10 11:41:01', '测试中': '2024-04-09 07:10:30', '待测试': '2024-04-08 09:51:21', '开发中': '2024-04-03 02:58:07', '技术评审完成': '2024-04-03 02:58:05', '技术方案设计中': '2024-04-03 02:57:56', '需求&UI评审完成': '2024-04-03 02:14:35', 'UI交互待评审': '2024-04-02 07:01:19', 'UI交互设计中': '2024-03-28 07:21:56', '需求评审通过待设计': '2024-03-27 06:50:02', '待需求评审': '2024-03-15 07:25:08', '待需求预审': '2024-03-15 07:25:01', '需求设计中': '2024-03-15 07:24:58'}
# {'已完成': '2024-04-07 10:14:14', '待发布': '2024-04-07 08:01:14', '待产品&UI验收': '2024-04-07 07:16:45', '测试中': '2024-04-01 09:38:42', '待测试': '2024-04-01 09:38:05', '开发中': '2024-03-19 02:09:20', '需求&UI评审完成': '2024-03-19 02:09:17', 'UI交互待评审': '2024-03-18 07:55:41', 'UI交互设计中': '2024-03-18 07:55:37', '需求评审通过待设计': '2024-03-14 03:51:23', '待需求评审': '2024-03-12 17:10:06', '待需求预审': '2024-03-12 17:10:00', '需求设计中': '2024-03-12 17:09:57'}
# {'已完成': '2024-04-16 01:59:18', '待测试': '2024-04-16 01:58:59', '开发中': '2024-04-16 01:58:50', '需求&UI评审完成': '2024-03-08 10:37:11', '待需求评审': '2024-03-08 10:36:57', '需求设计中': '2024-03-08 10:36:53'}
# {'计划开始时间': '2024-06-05 00:00:00', '计划完成时间': '2024-06-05 00:00:00', '变更后完成时间': '2024-06-06 00:00:00', '归属业务': 'CRM', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '2', 'sumPlanedLaborHour': '2'}
# {'已完成': '2024-06-06 02:03:14', '待发布': '2024-06-06 02:03:11', '待测试': '2024-06-06 02:03:01', '开发中': '2024-06-05 10:31:26', '需求&UI评审完成': '2024-06-05 10:31:17', '待需求评审': '2024-06-05 07:40:28', '需求设计中': '2024-06-05 07:40:24'}
# {'计划开始时间': '2024-06-04 00:00:00', '计划完成时间': '2024-06-06 00:00:00', '变更后完成时间': '2024-06-06 00:00:00', '需求延期原因': '忘记点完成状态', '测试负责人': '618a2b22c596f7c2158c9456', '归属业务': '鲜沐商城', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '21', 'sumPlanedLaborHour': '24'}
# {'已完成': '2024-06-07 01:30:43', '待产品&UI验收': '2024-06-06 10:08:27', '测试中': '2024-06-06 10:07:43', '待测试': '2024-06-06 10:07:34', '开发中': '2024-06-05 10:31:15', '技术评审完成': '2024-06-04 08:50:32', '技术方案设计中': '2024-06-04 07:14:24', '需求&UI评审完成': '2024-06-04 07:14:21', '待需求评审': '2024-06-04 07:13:07', '待需求预审': '2024-06-04 07:12:47', '需求设计中': '2024-06-04 07:12:45'}
# {'计划开始时间': '2024-06-03 00:00:00', '计划完成时间': '2024-06-07 00:00:00', '归属业务': '鲜沐商城', '优先级': 'e5d3d463361fe45fafc01a3b8a', 'sumActualLaborHour': '14.5', 'sumPlanedLaborHour': '13.5'}
# {'已完成': '2024-06-07 02:07:06', '待发布': '2024-06-07 02:06:58', '待测试': '2024-06-07 02:06:45', '开发中': '2024-06-05 02:08:44', '技术评审完成': '2024-06-05 02:08:39', '技术方案设计中': '2024-06-03 11:02:45', '需求&UI评审完成': '2024-06-03 11:02:42'}
# {'计划开始时间': '2024-05-30 00:00:00', '计划完成时间': '2024-06-04 00:00:00', '变更后完成时间': '2024-06-07 00:00:00', '归属业务': '鲜沐商城', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '32.5', 'sumPlanedLaborHour': '36'}
# {'已完成': '2024-06-07 01:23:14', '待测试': '2024-06-05 10:32:05', '开发中': '2024-05-30 01:54:19', '需求&UI评审完成': '2024-05-30 01:53:59'}
# {'计划开始时间': '2024-05-30 00:00:00', '计划完成时间': '2024-06-05 00:00:00', '归属业务': 'CRM', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '22.5', 'sumPlanedLaborHour': '24'}
# {'已完成': '2024-06-05 10:49:19', '待测试': '2024-06-05 10:49:14', '开发中': '2024-06-05 10:49:09', '技术评审完成': '2024-06-05 10:48:59', '技术方案设计中': '2024-05-30 10:35:00', '需求&UI评审完成': '2024-05-30 10:34:54', '待需求评审': '2024-05-30 10:34:45', '需求设计中': '2024-05-29 02:55:23'}
# {'计划开始时间': '2024-05-29 00:00:00', '计划完成时间': '2024-06-05 00:00:00', '测试负责人': '636214507b63b44dd78ba94f', '归属业务': '鲜沐商城', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '59.5', 'sumPlanedLaborHour': '70.5'}
# {'已完成': '2024-06-05 10:31:04', '待发布': '2024-06-05 02:22:45', '待产品&UI验收': '2024-06-05 02:01:14', '测试中': '2024-06-04 01:39:56', '待测试': '2024-06-03 07:13:06', '开发中': '2024-05-30 05:51:10', '技术评审完成': '2024-05-30 05:51:06', '技术方案设计中': '2024-05-30 01:43:44', '需求&UI评审完成': '2024-05-29 06:46:32', '待需求预审': '2024-05-29 02:08:53', '需求设计中': '2024-05-29 02:08:49'}
# {'计划开始时间': '2024-05-28 00:00:00', '计划完成时间': '2024-06-03 00:00:00', '归属业务': '鲜沐商城', '优先级': 'e5d3d463361fe45fafc01a3b8a', 'sumActualLaborHour': '13.5', 'sumPlanedLaborHour': '13.5'}
# {'已完成': '2024-06-03 02:12:20', '待发布': '2024-06-03 02:12:18', '待测试': '2024-06-03 02:12:11', '开发中': '2024-06-03 02:12:06', '技术评审完成': '2024-06-03 02:12:01', '技术方案设计中': '2024-05-28 01:59:33', '需求&UI评审完成': '2024-05-28 01:59:07', '需求设计中': '2024-05-28 01:58:58'}
# {'计划开始时间': '2024-05-28 00:00:00', '计划完成时间': '2024-05-28 00:00:00', '归属业务': 'SaaS', '优先级': '44d682a24fb3bb43256e177402', 'sumActualLaborHour': '0.5', 'sumPlanedLaborHour': '0.5'}
# {'已完成': '2024-05-28 02:11:51', '待测试': '2024-05-28 02:11:48', '开发中': '2024-05-28 02:11:40', '需求&UI评审完成': '2024-05-28 02:10:19', '待需求评审': '2024-05-22 02:27:32', '待需求预审': '2024-05-22 02:27:29', '需求设计中': '2024-05-22 02:27:26'}
# {'计划开始时间': '2024-05-20 00:00:00', '计划完成时间': '2024-05-21 00:00:00', '变更后完成时间': '2024-05-24 00:00:00', '测试负责人': '64daf5533b187bc174b88ccb', '归属业务': 'CRM', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '31', 'sumPlanedLaborHour': '21'}
# {'已完成': '2024-05-24 11:08:09', '待产品&UI验收': '2024-05-24 11:07:34', '测试中': '2024-05-24 11:07:17', '待测试': '2024-05-24 11:07:08', '开发中': '2024-05-20 10:51:29', '技术评审完成': '2024-05-20 06:31:08', '技术方案设计中': '2024-05-20 06:31:01', '需求&UI评审完成': '2024-05-20 06:30:57', '待需求评审': '2024-05-17 09:29:37', '需求设计中': '2024-05-17 09:29:33'}
# {'计划开始时间': '2024-05-28 00:00:00', '计划完成时间': '2024-05-31 00:00:00', '归属业务': 'SaaS', '优先级': 'e5d3d463361fe45fafc01a3b8a', 'sumActualLaborHour': '2', 'sumPlanedLaborHour': '2'}
# {'已完成': '2024-05-28 07:43:14', '待测试': '2024-05-28 07:43:11', '开发中': '2024-05-28 02:11:20', '需求&UI评审完成': '2024-05-28 02:07:41', '待需求评审': '2024-05-16 09:30:16', '需求设计中': '2024-05-16 09:30:15', '待需求预审': '2024-05-16 09:30:12'}
# {'计划开始时间': '2024-05-16 00:00:00', '计划完成时间': '2024-05-16 00:00:00', '归属业务': 'SaaS', '优先级': '0728daf9f805c041f3076a63ad', 'sumActualLaborHour': '3.5', 'sumPlanedLaborHour': '7.5'}
# {'已完成': '2024-05-16 07:08:37', '待测试': '2024-05-16 07:08:34', '开发中': '2024-05-16 07:08:25', '需求&UI评审完成': '2024-05-16 07:08:04', '待需求评审': '2024-05-16 07:06:46', '待需求预审': '2024-05-16 07:06:44', '需求设计中': '2024-05-16 07:06:43'}
# {'计划开始时间': '2024-05-15 00:00:00', '计划完成时间': '2024-05-20 00:00:00', '测试负责人': '638841c1a5d2aaf80fb3a31c', '归属业务': '鲜沐商城', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '11', 'sumPlanedLaborHour': '12'}
# {'已完成': '2024-05-20 10:05:45', '待产品&UI验收': '2024-05-20 10:05:00', '测试中': '2024-05-17 08:06:23', '待测试': '2024-05-17 08:06:13', '开发中': '2024-05-15 10:59:12', '需求&UI评审完成': '2024-05-15 10:58:55', '待需求评审': '2024-05-14 09:09:12', '待需求预审': '2024-05-14 09:05:04', '需求设计中': '2024-05-14 09:05:02'}
# {'计划开始时间': '2024-05-29 00:00:00', '计划完成时间': '2024-06-05 00:00:00', '归属业务': '鲜沐商城', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '24.5', 'sumPlanedLaborHour': '27.0'}
# {'已完成': '2024-06-05 08:55:35', '待产品&UI验收': '2024-06-04 11:08:13', '待测试': '2024-06-04 11:08:07', '开发中': '2024-05-29 11:15:11', '需求&UI评审完成': '2024-05-29 11:14:53', '需求评审通过待设计': '2024-05-24 09:29:54', '待需求评审': '2024-05-24 08:56:52', '待需求预审': '2024-05-14 06:49:08', '需求设计中': '2024-05-14 06:49:06'}
# {'计划开始时间': '2024-05-14 00:00:00', '计划完成时间': '2024-05-30 00:00:00', '测试负责人': '636214507b63b44dd78ba94f', '归属业务': '鲜沐商城', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '36.0', 'sumPlanedLaborHour': '44'}
# {'已完成': '2024-05-22 03:11:50', '待产品&UI验收': '2024-05-21 05:43:30', '测试中': '2024-05-20 09:36:43', '待测试': '2024-05-20 09:36:28', '开发中': '2024-05-15 09:19:08', '技术评审完成': '2024-05-15 09:19:03', '技术方案设计中': '2024-05-14 06:55:40', '需求&UI评审完成': '2024-05-14 06:55:36', '待需求评审': '2024-05-14 06:05:45', '待需求预审': '2024-05-14 02:59:01', '需求设计中': '2024-05-14 02:58:58'}
# {'计划开始时间': '2024-04-26 00:00:00', '计划完成时间': '2024-04-28 00:00:00', '测试负责人': '618a2b22c596f7c2158c9456', '归属业务': '财务相关（应收&应付）', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '5', 'sumPlanedLaborHour': '5'}
# {'已完成': '2024-04-28 10:12:06', '待产品&UI验收': '2024-04-28 10:11:26', '测试中': '2024-04-28 02:01:42', '待测试': '2024-04-26 11:01:58', '开发中': '2024-04-26 11:01:46', '需求&UI评审完成': '2024-04-26 11:01:28', '待需求评审': '2024-04-25 10:50:13', '待需求预审': '2024-04-25 10:50:10', '需求设计中': '2024-04-25 10:50:08'}
# {'计划开始时间': '2024-04-26 00:00:00', '计划完成时间': '2024-04-30 00:00:00', '变更后完成时间': '2024-05-10 00:00:00', '归属业务': 'CRM', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '52.5', 'sumPlanedLaborHour': '57.0'}
# {'已完成': '2024-05-10 02:11:11', '待测试': '2024-05-10 02:11:07', '开发中': '2024-04-30 02:05:18', '需求&UI评审完成': '2024-04-26 02:06:28', '待需求评审': '2024-04-25 02:12:57', '需求设计中': '2024-04-25 02:12:54'}
# {'计划开始时间': '2024-04-25 00:00:00', '计划完成时间': '2024-04-28 00:00:00', '测试负责人': '', '归属业务': '鲜沐商城', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '12', 'sumPlanedLaborHour': '12'}
# {'已完成': '2024-04-28 08:20:28', '待产品&UI验收': '2024-04-28 02:16:07', '测试中': '2024-04-25 10:30:51', '待测试': '2024-04-25 10:30:37', '开发中': '2024-04-25 10:30:27', '需求&UI评审完成': '2024-04-25 03:44:05', '待需求评审': '2024-04-24 11:18:42', '待需求预审': '2024-04-24 11:18:38', '需求设计中': '2024-04-24 11:18:32'}
# {'计划开始时间': '2024-05-21 00:00:00', '计划完成时间': '2024-06-03 00:00:00', '测试负责人': '636214507b63b44dd78ba94f', '归属业务': 'SaaS', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '83.5', 'sumPlanedLaborHour': '116.5'}
# {'已完成': '2024-06-03 11:03:13', '待产品&UI验收': '2024-06-03 01:56:22', '测试中': '2024-05-31 09:05:20', '待测试': '2024-05-31 02:49:38', '开发中': '2024-05-23 02:02:51', '技术评审完成': '2024-05-22 09:51:36', '技术方案设计中': '2024-05-22 05:59:34', '需求&UI评审完成': '2024-05-21 02:17:20', '待需求评审': '2024-04-24 03:50:14', '待需求预审': '2024-04-24 03:50:06', '需求设计中': '2024-04-24 03:50:04'}
# {'计划开始时间': '2024-04-26 00:00:00', '计划完成时间': '2024-05-29 00:00:00', '测试负责人': '6257f3522c14288da072b844', '归属业务': '财务相关（应收&应付）', '优先级': '0728daf9f805c041f3076a63ad', 'sumActualLaborHour': '80.0', 'sumPlanedLaborHour': '102.0'}
# {'已完成': '2024-05-27 10:43:18', '待发布': '2024-05-27 10:37:49', '待产品&UI验收': '2024-05-27 10:35:33', '测试中': '2024-05-27 10:35:25', '待测试': '2024-05-20 11:12:47', '开发中': '2024-05-10 00:37:52', '技术评审完成': '2024-05-10 00:37:50', '技术方案设计中': '2024-04-26 09:15:21', '需求&UI评审完成': '2024-04-26 02:19:48', '待需求评审': '2024-04-24 11:18:45', '待需求预审': '2024-04-24 11:18:35', '需求设计中': '2024-04-22 10:55:08'}
# {'计划开始时间': '2024-04-24 00:00:00', '计划完成时间': '2024-04-28 00:00:00', '测试负责人': '618a2b22c596f7c2158c9456', '归属业务': '鲜沐商城', '优先级': 'e5d3d463361fe45fafc01a3b8a', 'sumActualLaborHour': '6', 'sumPlanedLaborHour': '6'}
# {'已完成': '2024-04-28 12:29:32', '待产品&UI验收': '2024-04-28 02:16:01', '测试中': '2024-04-28 02:13:40', '待测试': '2024-04-28 02:13:30', '开发中': '2024-04-26 02:20:17', '需求&UI评审完成': '2024-04-24 08:40:18', '待需求预审': '2024-04-22 03:03:51', '需求设计中': '2024-04-22 03:03:48'}
# {'计划开始时间': '2024-04-19 00:00:00', '计划完成时间': '2024-04-19 00:00:00', '归属业务': 'SaaS', '优先级': '0728daf9f805c041f3076a63ad', 'sumActualLaborHour': '8', 'sumPlanedLaborHour': '8'}
# {'已完成': '2024-04-19 03:57:17', '待测试': '2024-04-19 03:57:08', '开发中': '2024-04-19 03:56:37', '需求&UI评审完成': '2024-04-19 03:55:03', '待需求评审': '2024-04-19 03:45:25', '待需求预审': '2024-04-19 03:45:19', '需求设计中': '2024-04-19 03:45:16'}
# {'计划开始时间': '2024-04-18 00:00:00', '计划完成时间': '2024-04-19 00:00:00', '测试负责人': '637c8e597b63b44dd73fb0dc', '归属业务': 'CRM', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '11', 'sumPlanedLaborHour': '11'}
# {'已完成': '2024-04-19 08:44:19', '待产品&UI验收': '2024-04-19 08:00:10', '测试中': '2024-04-19 07:35:42', '待测试': '2024-04-19 07:35:33', '开发中': '2024-04-18 09:18:56', '需求&UI评审完成': '2024-04-18 09:18:54', '待需求评审': '2024-04-18 05:42:49', '需求设计中': '2024-04-18 05:42:45'}
# {'计划开始时间': '2024-04-22 00:00:00', '计划完成时间': '2024-05-15 00:00:00', '归属业务': '鲜沐商城', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '135.0', 'sumPlanedLaborHour': '158.0'}
# {'已完成': '2024-05-15 11:04:58', '待发布': '2024-05-13 03:24:36', '待测试': '2024-05-11 06:51:35', '开发中': '2024-04-28 09:36:53', '技术评审完成': '2024-04-28 09:36:47', '技术方案设计中': '2024-04-23 02:49:22', '需求&UI评审完成': '2024-04-22 10:02:02', '待需求预审': '2024-04-18 02:15:00', '需求设计中': '2024-04-18 02:14:58'}
# {'计划开始时间': '2024-04-18 00:00:00', '计划完成时间': '2024-04-23 00:00:00', '归属业务': '鲜沐商城', '优先级': 'e5d3d463361fe45fafc01a3b8a', 'sumActualLaborHour': '35.0', 'sumPlanedLaborHour': '37.5'}
# {'已完成': '2024-04-23 10:31:30', '待发布': '2024-04-23 05:34:37', '待测试': '2024-04-22 01:59:38', '开发中': '2024-04-18 01:56:05', '技术评审完成': '2024-04-18 01:56:01', '技术方案设计中': '2024-04-15 02:09:52', '需求&UI评审完成': '2024-04-15 02:09:48'}
# {'计划开始时间': '2024-04-11 00:00:00', '计划完成时间': '2024-04-15 00:00:00', '测试负责人': '637c8e597b63b44dd73fb0dc', '归属业务': '鲜沐商城', '优先级': '0728daf9f805c041f3076a63ad', 'sumActualLaborHour': '25', 'sumPlanedLaborHour': '26'}
# {'已完成': '2024-04-15 10:50:59', '待产品&UI验收': '2024-04-15 08:27:42', '测试中': '2024-04-15 08:08:03', '待测试': '2024-04-15 02:15:09', '开发中': '2024-04-12 03:10:17', '需求&UI评审完成': '2024-04-11 08:07:58', '待需求评审': '2024-04-11 06:13:24', '需求设计中': '2024-04-11 06:13:21'}
# {'计划开始时间': '2024-04-17 00:00:00', '计划完成时间': '2024-05-31 00:00:00', '归属业务': 'SaaS', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '32.5', 'sumPlanedLaborHour': '40'}
# {'已完成': '2024-05-28 09:58:01', '待发布': '2024-05-27 03:00:46', '待测试': '2024-05-20 01:53:38', '开发中': '2024-05-06 02:49:33', '技术评审完成': '2024-05-06 02:49:03', '技术方案设计中': '2024-04-17 02:04:15', '需求&UI评审完成': '2024-04-17 02:04:11', '待需求评审': '2024-04-10 11:49:57', '待需求预审': '2024-04-10 11:49:54', '需求设计中': '2024-04-10 11:49:53'}
# {'计划开始时间': '2024-04-19 00:00:00', '计划完成时间': '2024-05-07 00:00:00', '归属业务': 'SaaS', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '24', 'sumPlanedLaborHour': '23'}
# {'已完成': '2024-05-07 02:52:59', '待测试': '2024-05-07 02:52:56', '开发中': '2024-04-28 10:59:47', '需求&UI评审完成': '2024-04-24 02:05:15', 'UI交互设计中': '2024-04-22 07:53:23', '需求评审通过待设计': '2024-04-19 02:50:40', '待需求评审': '2024-04-09 10:44:18', '待需求预审': '2024-04-09 10:44:14', '需求设计中': '2024-04-09 10:44:12'}
# {'计划开始时间': '2024-04-10 00:00:00', '计划完成时间': '2024-04-16 00:00:00', '归属业务': 'SaaS', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '8.5', 'sumPlanedLaborHour': '8.5'}
# {'已完成': '2024-04-12 10:50:04', '待产品&UI验收': '2024-04-12 08:03:53', '待测试': '2024-04-12 08:03:25', '开发中': '2024-04-11 03:33:49', '需求&UI评审完成': '2024-04-10 10:57:02', '待需求评审': '2024-04-09 10:42:17', '待需求预审': '2024-04-09 10:42:09', '需求设计中': '2024-04-09 10:42:06'}
# {'计划开始时间': '2024-04-10 00:00:00', '计划完成时间': '2024-04-11 00:00:00', '测试负责人': '637c8e597b63b44dd73fb0dc', '归属业务': '鲜沐商城', '优先级': 'e5d3d463361fe45fafc01a3b8a', 'sumActualLaborHour': '6', 'sumPlanedLaborHour': '6'}
# {'已完成': '2024-04-10 10:11:11', '待产品&UI验收': '2024-04-10 10:11:08', '测试中': '2024-04-10 09:03:26', '待测试': '2024-04-10 09:03:04', '开发中': '2024-04-10 07:47:53', '需求&UI评审完成': '2024-04-10 02:02:13', '待需求评审': '2024-04-09 10:23:09', '需求设计中': '2024-04-09 10:23:06'}
# {'计划开始时间': '2024-04-09 00:00:00', '计划完成时间': '2024-04-09 00:00:00', '归属业务': 'CRM', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '3', 'sumPlanedLaborHour': '3'}
# {'已完成': '2024-04-09 03:49:49', '待测试': '2024-04-09 03:49:44', '开发中': '2024-04-09 02:51:45', '需求&UI评审完成': '2024-04-09 02:51:34', '需求设计中': '2024-04-09 02:40:40'}
# {'计划开始时间': '2024-04-10 00:00:00', '计划完成时间': '2024-04-15 00:00:00', '归属业务': 'SaaS', '优先级': 'e5d3d463361fe45fafc01a3b8a', 'sumActualLaborHour': '9.5', 'sumPlanedLaborHour': '15.5'}
# {'已完成': '2024-04-12 10:49:46', '待产品&UI验收': '2024-04-12 08:03:46', '待测试': '2024-04-12 08:03:33', '开发中': '2024-04-11 08:52:57', '需求&UI评审完成': '2024-04-10 10:56:17', '待需求评审': '2024-04-08 06:46:25', '待需求预审': '2024-04-08 06:46:18', '需求设计中': '2024-04-08 06:46:16'}
# {'计划开始时间': '2024-04-10 00:00:00', '计划完成时间': '2024-04-19 00:00:00', '测试负责人': '6257f3522c14288da072b844', '归属业务': 'SaaS', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '25.5', 'sumPlanedLaborHour': '26.5'}
# {'已完成': '2024-04-18 10:56:06', '待产品&UI验收': '2024-04-18 08:04:23', '测试中': '2024-04-18 02:30:52', '待测试': '2024-04-12 09:05:26', '开发中': '2024-04-11 08:55:55', '需求&UI评审完成': '2024-04-10 10:56:35', '待需求评审': '2024-04-08 06:43:18', '待需求预审': '2024-04-08 06:43:03', '需求设计中': '2024-04-08 06:43:00'}
# {'计划开始时间': '2024-04-02 00:00:00', '计划完成时间': '2024-04-08 00:00:00', '测试负责人': '619323b7c596f7c215d1a67f', '优先级': '0728daf9f805c041f3076a63ad', 'sumActualLaborHour': '25.5', 'sumPlanedLaborHour': '29.5'}
# {'已完成': '2024-04-07 08:05:13', '待产品&UI验收': '2024-04-07 08:04:59', '测试中': '2024-04-07 08:04:45', '待测试': '2024-04-07 08:04:36', '开发中': '2024-04-01 11:07:33', '技术评审完成': '2024-04-01 11:07:31', '技术方案设计中': '2024-04-01 11:07:28', '需求&UI评审完成': '2024-03-29 02:04:37', '待需求评审': '2024-03-28 03:16:09', '待需求预审': '2024-03-28 03:16:06', '需求设计中': '2024-03-28 03:16:03'}
# {'计划开始时间': '2024-03-29 00:00:00', '计划完成时间': '2024-04-02 00:00:00', '优先级': 'e5d3d463361fe45fafc01a3b8a', 'sumActualLaborHour': '11', 'sumPlanedLaborHour': '12'}
# {'已完成': '2024-04-02 07:28:20', '待测试': '2024-04-02 02:06:11', '开发中': '2024-04-01 02:12:22', '需求&UI评审完成': '2024-03-29 02:05:45', '待需求预审': '2024-03-21 07:48:12', '需求设计中': '2024-03-21 05:58:44'}
# {'计划开始时间': '2024-03-28 00:00:00', '计划完成时间': '2024-04-10 00:00:00', '测试负责人': '636214507b63b44dd78ba94f', '归属业务': 'SaaS', '优先级': 'e5d3d463361fe45fafc01a3b8a', 'sumActualLaborHour': '50.0', 'sumPlanedLaborHour': '70'}
# {'已完成': '2024-04-09 07:09:44', '待发布': '2024-04-09 07:09:05', '待产品&UI验收': '2024-04-09 06:57:36', '测试中': '2024-04-08 02:01:34', '待测试': '2024-04-08 02:01:27', '开发中': '2024-03-29 08:46:48', '需求&UI评审完成': '2024-03-25 02:12:59', '待需求预审': '2024-03-21 09:56:53', '需求设计中': '2024-03-21 03:28:44'}
# {'计划开始时间': '2024-04-07 00:00:00', '计划完成时间': '2024-04-23 00:00:00', '测试负责人': '636214507b63b44dd78ba94f', '归属业务': 'SaaS', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '171.0', 'sumPlanedLaborHour': '207.0'}
# {'已完成': '2024-04-23 09:49:57', '待产品&UI验收': '2024-04-23 05:50:53', '测试中': '2024-04-16 09:20:11', '待测试': '2024-04-16 09:20:08', '开发中': '2024-04-09 08:17:38', '需求&UI评审完成': '2024-04-07 08:22:27', '待需求评审': '2024-03-29 05:44:24', '待需求预审': '2024-03-29 05:44:18', '需求设计中': '2024-03-15 07:27:21'}
# {'计划开始时间': '2024-03-27 00:00:00', '计划完成时间': '2024-04-11 00:00:00', '测试负责人': '636214507b63b44dd78ba94f', '归属业务': 'SaaS', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '69.5', 'sumPlanedLaborHour': '64.5'}
# {'已完成': '2024-04-11 11:10:46', '待发布': '2024-04-10 11:50:56', '待产品&UI验收': '2024-04-10 11:41:01', '测试中': '2024-04-09 07:10:30', '待测试': '2024-04-08 09:51:21', '开发中': '2024-04-03 02:58:07', '技术评审完成': '2024-04-03 02:58:05', '技术方案设计中': '2024-04-03 02:57:56', '需求&UI评审完成': '2024-04-03 02:14:35', 'UI交互待评审': '2024-04-02 07:01:19', 'UI交互设计中': '2024-03-28 07:21:56', '需求评审通过待设计': '2024-03-27 06:50:02', '待需求评审': '2024-03-15 07:25:08', '待需求预审': '2024-03-15 07:25:01', '需求设计中': '2024-03-15 07:24:58'}
# {'计划开始时间': '2024-03-18 00:00:00', '计划完成时间': '2024-03-27 00:00:00', '变更后完成时间': '2024-04-07 00:00:00', '需求延期原因': '测试及后端开发人员变动', '测试负责人': '636214507b63b44dd78ba94f', '优先级': '6ea27ca204dc0fe9d9bbff462d', 'sumActualLaborHour': '72.5', 'sumPlanedLaborHour': '97.5'}
# {'已完成': '2024-04-07 10:14:14', '待发布': '2024-04-07 08:01:14', '待产品&UI验收': '2024-04-07 07:16:45', '测试中': '2024-04-01 09:38:42', '待测试': '2024-04-01 09:38:05', '开发中': '2024-03-19 02:09:20', '需求&UI评审完成': '2024-03-19 02:09:17', 'UI交互待评审': '2024-03-18 07:55:41', 'UI交互设计中': '2024-03-18 07:55:37', '需求评审通过待设计': '2024-03-14 03:51:23', '待需求评审': '2024-03-12 17:10:06', '待需求预审': '2024-03-12 17:10:00', '需求设计中': '2024-03-12 17:09:57'}
# {'计划开始时间': '2024-03-08 00:00:00', '计划完成时间': '2024-04-16 00:00:00', '归属业务': '鲜沐商城', '优先级': 'e5d3d463361fe45fafc01a3b8a', 'sumActualLaborHour': '88', 'sumPlanedLaborHour': '80'}
# {'已完成': '2024-04-16 01:59:18', '待测试': '2024-04-16 01:58:59', '开发中': '2024-04-16 01:58:50', '需求&UI评审完成': '2024-03-08 10:37:11', '待需求评审': '2024-03-08 10:36:57', '需求设计中': '2024-03-08 10:36:53'}

# %%
items_df=pd.DataFrame(work_item_info_list)
items_df['gmtModified'] = pd.to_datetime(items_df['gmtModified'], unit='ms')
items_df['finishTime'] = pd.to_datetime(items_df['finishTime'], unit='ms')
items_df['gmtCreate'] = pd.to_datetime(items_df['gmtCreate'], unit='ms')
items_df['updateStatusAt'] = pd.to_datetime(items_df['updateStatusAt'], unit='ms')
# Convert the specific key value to datetime
items_df['研发开始时间'] = items_df['custom_fields_dict'].apply(lambda x: pd.to_datetime(x.get('计划开始时间')))
items_df['计划发布时间'] = items_df['custom_fields_dict'].apply(lambda x: pd.to_datetime(x.get('计划完成时间')))
# sumActualLaborHour
items_df['需求总工时'] = items_df['custom_fields_dict'].apply(lambda x: pd.to_numeric(x.get('sumActualLaborHour')))

# Calculate the difference in seconds between two datetime columns
items_df['研发人日'] = (items_df['计划发布时间'] - items_df['研发开始时间']).dt.total_seconds() / (24 * 3600)

# Round the result to one decimal place
items_df['研发人日'] = items_df['研发人日'].round(1)
# Create a new column '是否延期' with boolean values
items_df['是否延期'] = items_df['finishTime'].dt.date > items_df['计划发布时间'].dt.date

# Convert boolean values to 1 for True and 0 for False
items_df['是否延期'] = items_df['是否延期'].astype(int)
items_df.describe()
# Out:
#             需求总工时       研发人日       是否延期
# count   39.000000  39.000000  39.000000
# mean    33.935897   8.692308   0.153846
# std     37.503365  10.438173   0.365518
# min      0.500000   0.000000   0.000000
# 25%      9.000000   2.500000   0.000000
# 50%     24.000000   5.000000   0.000000
# 75%     43.000000  11.000000   0.000000
# max    171.000000  44.000000   1.000000

# %%
import datetime

yyyymmdd=datetime.datetime.now().strftime('%Y-%m-%d')
items_df.to_csv(f'./data/saas云效-{start_date}_{end_date}_at_{yyyymmdd}.csv', index=False)

# %%
# Set the option to display full column width
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)  # Set to None to display all rows
pd.set_option('display.max_columns', None)  # Set to None to display all columns
pd.set_option('display.width', None)  # Set width to None for automatic wrapping

all_timing_fields=['已完成','待产品&UI验收','待测试','开发中','需求&UI评审完成','待需求评审','测试中','技术评审完成','技术方案设计中','需求设计中','待发布']
items_to_analytics_df=items_df[['subject','研发人日','是否延期','需求总工时','activities_dict','gmtCreate','计划发布时间']]
for timing_field in all_timing_fields:
    items_to_analytics_df[timing_field]=items_to_analytics_df['activities_dict'].apply(lambda x: pd.to_datetime(x.get(timing_field)))

items_to_analytics_df['需求分析时长D'] = (items_to_analytics_df['需求&UI评审完成'] - items_to_analytics_df['需求设计中']).dt.total_seconds() / (24 * 3600)
items_to_analytics_df['需求纯开发时长D'] = (items_to_analytics_df['待测试'] - items_to_analytics_df['开发中']).dt.total_seconds() / (24 * 3600)
items_to_analytics_df['需求纯测试时长D'] = (items_to_analytics_df['待产品&UI验收'] - items_to_analytics_df['待测试']).dt.total_seconds() / (24 * 3600)
items_to_analytics_df['需求纯技术设计时长D'] = (items_to_analytics_df['开发中'] - items_to_analytics_df['需求&UI评审完成']).dt.total_seconds() / (24 * 3600)
# Calculate the difference in seconds between two datetime columns
items_to_analytics_df['研发人日'] = (items_to_analytics_df['已完成'] - items_to_analytics_df['需求&UI评审完成']).dt.total_seconds() / (24 * 3600)
items_to_analytics_df['已完成-需求&UI评审完成'] = (items_to_analytics_df['已完成'] - items_to_analytics_df['需求&UI评审完成']).dt.days
items_to_analytics_df.head(1)
# Out:
# /var/folders/cl/v_4j9fbj5nn_jj6q9d3r5ggc0000gn/T/ipykernel_83375/2564869647.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   items_to_analytics_df[timing_field]=items_to_analytics_df['activities_dict'].apply(lambda x: pd.to_datetime(x.get(timing_field)))
# /var/folders/cl/v_4j9fbj5nn_jj6q9d3r5ggc0000gn/T/ipykernel_83375/2564869647.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   items_to_analytics_df['需求分析时长D'] = (items_to_analytics_df['需求&UI评审完成'] - items_to_analytics_df['需求设计中']).dt.total_seconds() / (24 * 3600)
# /var/folders/cl/v_4j9fbj5nn_jj6q9d3r5ggc0000gn/T/ipykernel_83375/2564869647.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   items_to_analytics_df['需求纯开发时长D'] = (items_to_analytics_df['待测试'] - items_to_analytics_df['开发中']).dt.total_seconds() / (24 * 3600)
# /var/folders/cl/v_4j9fbj5nn_jj6q9d3r5ggc0000gn/T/ipykernel_83375/2564869647.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   items_to_analytics_df['需求纯测试时长D'] = (items_to_analytics_df['待产品&UI验收'] - items_to_analytics_df['待测试']).dt.total_seconds() / (24 * 3600)
# /var/folders/cl/v_4j9fbj5nn_jj6q9d3r5ggc0000gn/T/ipykernel_83375/2564869647.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   items_to_analytics_df['需求纯技术设计时长D'] = (items_to_analytics_df['开发中'] - items_to_analytics_df['需求&UI评审完成']).dt.total_seconds() / (24 * 3600)
# /var/folders/cl/v_4j9fbj5nn_jj6q9d3r5ggc0000gn/T/ipykernel_83375/2564869647.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   items_to_analytics_df['研发人日'] = (items_to_analytics_df['已完成'] - items_to_analytics_df['需求&UI评审完成']).dt.total_seconds() / (24 * 3600)
# /var/folders/cl/v_4j9fbj5nn_jj6q9d3r5ggc0000gn/T/ipykernel_83375/2564869647.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   items_to_analytics_df['已完成-需求&UI评审完成'] = (items_to_analytics_df['已完成'] - items_to_analytics_df['需求&UI评审完成']).dt.days
#          subject      研发人日  是否延期  需求总工时  \
# 0  【CRM】任务标签名可配置  0.647188     1    2.0
#
#                                                                                                                                                                                                                 activities_dict  \
# 0  {'已完成': '2024-06-06 02:03:14', '待发布': '2024-06-06 02:03:11', '待测试': '2024-06-06 02:03:01', '开发中': '2024-06-05 10:31:26', '需求&UI评审完成': '2024-06-05 10:31:17', '待需求评审': '2024-06-05 07:40:28', '需求设计中': '2024-06-05 07:40:24'}
#
#             gmtCreate     计划发布时间                 已完成 待产品&UI验收  \
# 0 2024-06-05 07:40:17 2024-06-05 2024-06-06 02:03:14      NaT
#
#                   待测试                 开发中           需求&UI评审完成  \
# 0 2024-06-06 02:03:01 2024-06-05 10:31:26 2024-06-05 10:31:17
#
#                 待需求评审 测试中 技术评审完成 技术方案设计中               需求设计中  \
# 0 2024-06-05 07:40:28 NaT    NaT     NaT 2024-06-05 07:40:24
#
#                   待发布   需求分析时长D  需求纯开发时长D  需求纯测试时长D  需求纯技术设计时长D  已完成-需求&UI评审完成
# 0 2024-06-06 02:03:11  0.118669  0.646933       NaN    0.000104              0

# %% [markdown]
# ## 研发人日小于等于10天需求百分比%

# %%
import pandas as pd
import pandasql

column_name = 'activities_dict'
if column_name in items_to_analytics_df.columns:
    items_to_analytics_df.drop(columns=column_name, inplace=True)
# items_to_analytics_df.drop("activities_dict")
stat=pandasql.sqldf("""
                    select 
                    count(1) as `需求总数`,
                    count(case when `研发人日` >= 11 then 1 end) as `研发人日大于10天需求数`,
                    round(count(case when `研发人日` < 11 then 1 end)*100.00/count(1),2) as `研发人日小于等于10天需求百分比%`,
                    round(sum(`研发人日`)/count(1),2) as `avg研发人日D`,
                    round(sum(`需求总工时`)/count(1),2) as `avg研发工时H`,
                    count(case when `是否延期` > 0 then 1 end) as `延期需求数`,
                    count(case when `需求总工时` > 100 then 1 end) as `100h以上的需求数`
                    from items_to_analytics_df
                    """)

display(stat)
# Out:
# /Users/tangpeng/Documents/github/.venv/lib/python3.10/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#    需求总数  研发人日大于10天需求数  研发人日小于等于10天需求百分比%  avg研发人日D  avg研发工时H  延期需求数  \
# 0    39            10              74.36      8.74     33.94      6
#
#    100h以上的需求数
# 0           2

# %%
stat=pandasql.sqldf("""
                    select 
                    round(avg(`需求分析时长D`),2) as `avg需求分析时长D`,
                    round(avg(`需求纯开发时长D`),2) as `avg需求纯开发时长D`,
                    round(avg(`需求纯测试时长D`),2) as `avg需求纯测试时长D`,
                    round(avg(`需求纯技术设计时长D`),2) as `需求纯技术设计时长D`,
                    count(case when `需求纯开发时长D` >= 7 then 1 end) as `需求纯开发时长D>=7需求数`,
                    count(case when `需求纯测试时长D` >= 3 then 1 end) as `需求纯测试时长D>=3需求数`,
                    count(case when `需求纯技术设计时长D` >= 2 then 1 end) as `需求纯技术设计D>=2需求数`,
                    count(1) as `总需求数`
                    from items_to_analytics_df
                    """)
display(stat)
# Out:
#    avg需求分析时长D  avg需求纯开发时长D  avg需求纯测试时长D  需求纯技术设计时长D  需求纯开发时长D>=7需求数  \
# 0        4.64         3.86         1.94        3.24               9
#
#    需求纯测试时长D>=3需求数  需求纯技术设计D>=2需求数  总需求数
# 0               5              12    39

# %% [markdown]
# ## 研发人日>=10天的项目列表

# %%
from IPython.display import display

stat=pandasql.sqldf("""
                    select 
                    subject
                    ,round(`研发人日`,1) as `研发人日D`
                    ,round(`需求纯开发时长D`,1) as `需求纯开发时长D`
                    ,round(`需求纯测试时长D`,1) as `需求纯测试时长D`
                    ,date(`已完成`) as `完成日期`
                    ,date(`需求&UI评审完成`) as `需求评审完成日期`
                    ,date(`开发中`) as `首次进入开发中时间`
                    ,case when date(`需求&UI评审完成`) <= date('2024-05-01') then '五一前评审' else '否' end as `是否经历假期`
                    ,`已完成-需求&UI评审完成` as `研发时长D`
                    ,`需求总工时`,
                    round(`需求总工时`/`已完成-需求&UI评审完成`,1) as `avg工时per研发人日`
                    from items_to_analytics_df
                    where `研发人日` >=11
                    and `需求总工时`>0
                    order by `完成日期` desc
                    """)
# Set the option to display full column width
pd.set_option('display.max_colwidth', None)
display(stat)
# Out:
#                                                            subject  研发人日D  \
# 0                                                       SaaS支持快递链路   13.4
# 1                                                   对接三方仓(绝配)打通订单流   41.3
# 2                                                   【财务】销项发票切换为数电票   31.3
# 3                                                      商品管理-商品标签能力   23.0
# 4                                              【CRM】5月鲜果/PT奶油任务产品化   14.0
# 5                                       【SaaS】帆台官网For ICP：增加付费资讯栏目   13.0
# 6                                                            全品类接入   16.1
# 7                                                             定价分析   38.6
# 8  ‍​⁢﻿‍‬‬‬‍﻿‍‬‬‍⁢⁣‍​﻿⁢‌⁢‬​⁤‌‍⁢​‍⁣﻿‍‬⁣⁢⁣⁣⁡⁤‌‍⁤⁢‍⁤⁢‌​​帆台-售后支持上传视频素材   15.2
# 9                                                      需求-帆台报价模式升级   19.3
#
#    需求纯开发时长D  需求纯测试时长D        完成日期    需求评审完成日期   首次进入开发中时间 是否经历假期  研发时长D  \
# 0       8.0       3.0  2024-06-03  2024-05-21  2024-05-23      否     13
# 1      14.0       NaN  2024-05-28  2024-04-17  2024-05-06  五一前评审     41
# 2      10.4       7.0  2024-05-27  2024-04-26  2024-05-10  五一前评审     31
# 3      12.9       NaN  2024-05-15  2024-04-22  2024-04-28  五一前评审     23
# 4      10.0       NaN  2024-05-10  2024-04-26  2024-04-30  五一前评审     14
# 5       8.7       NaN  2024-05-07  2024-04-24  2024-04-28  五一前评审     13
# 6       7.0       6.9  2024-04-23  2024-04-07  2024-04-09  五一前评审     16
# 7       0.0       NaN  2024-04-16  2024-03-08  2024-04-16  五一前评审     38
# 8       9.7       1.2  2024-04-09  2024-03-25  2024-03-29  五一前评审     15
# 9      13.3       5.9  2024-04-07  2024-03-19  2024-03-19  五一前评审     19
#
#    需求总工时  avg工时per研发人日
# 0   83.5           6.4
# 1   32.5           0.8
# 2   80.0           2.6
# 3  135.0           5.9
# 4   52.5           3.8
# 5   24.0           1.8
# 6  171.0          10.7
# 7   88.0           2.3
# 8   50.0           3.3
# 9   72.5           3.8

# %% [markdown]
# ## 延期的项目

# %%
stat=pandasql.sqldf("""
                    select 
                    subject
                    ,round(`研发人日`,1) as `研发人日D`
                    ,date(`已完成`) as `完成日期`
                    ,date(`计划发布时间`) as `计划发布时间`
                    ,date(`需求&UI评审完成`) as `需求评审完成日期`
                    ,date(`开发中`) as `首次进入开发中时间`
                    ,case when date(`需求&UI评审完成`) <= date('2023-10-07') then '十一前评审' else '否' end as `是否经历假期`
                    ,`已完成-需求&UI评审完成` as `研发时长D`
                    ,`需求总工时`,
                    round(`需求总工时`/`已完成-需求&UI评审完成`,1) as `avg工时per研发人日`
                    from items_to_analytics_df
                    where `是否延期` > 0
                    order by `完成日期` desc
                    """)
display(stat)
# Out:
#                subject  研发人日D        完成日期      计划发布时间    需求评审完成日期   首次进入开发中时间  \
# 0    【商城】控价品下单链路隐藏优惠信息    2.8  2024-06-07  2024-06-06  2024-06-04  2024-06-05
# 1          【619】鲜沐年度账单    8.0  2024-06-07  2024-06-04  2024-05-30  2024-05-30
# 2        【CRM】任务标签名可配置    0.6  2024-06-06  2024-06-05  2024-06-05  2024-06-05
# 3   【CRM】企微销售-客户关系自动迁移    4.2  2024-05-24  2024-05-21  2024-05-20  2024-05-20
# 4  【CRM】5月鲜果/PT奶油任务产品化   14.0  2024-05-10  2024-04-30  2024-04-26  2024-04-30
# 5          需求-帆台报价模式升级   19.3  2024-04-07  2024-03-27  2024-03-19  2024-03-19
#
#   是否经历假期  研发时长D  需求总工时  avg工时per研发人日
# 0      否      2   21.0          10.5
# 1      否      7   32.5           4.6
# 2      否      0    2.0           NaN
# 3      否      4   31.0           7.8
# 4      否     14   52.5           3.8
# 5      否     19   72.5           3.8

# %%
df=items_to_analytics_df[['subject','已完成']].sort_values('已完成', ascending=False)
df.head(10)
# Out:
#               subject                 已完成
# 2        商城&CRM开票入口切换 2024-06-07 02:07:06
# 1   【商城】控价品下单链路隐藏优惠信息 2024-06-07 01:30:43
# 3         【619】鲜沐年度账单 2024-06-07 01:23:14
# 0       【CRM】任务标签名可配置 2024-06-06 02:03:14
# 4     【CRM】企微会话存档数据调取 2024-06-05 10:49:19
# 5        【营销】满返支持下单返券 2024-06-05 10:31:04
# 12       【商城】鲜果新增单价展示 2024-06-05 08:55:35
# 17         SaaS支持快递链路 2024-06-03 11:03:13
# 6            存量发票开具重试 2024-06-03 02:12:20
# 25     对接三方仓(绝配)打通订单流 2024-05-28 09:58:01
