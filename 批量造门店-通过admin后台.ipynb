# %%
import requests
import string
import random

url = 'https://admin.summerfarm.net/sf-mall-manage/merchant/upsert/insert'

headers = {
    'token': 'admin__e55f7b8a-0e31-4682-91d6-d903d8d61a87',
    'xm-rqid': 'create_fake_merchant_tp',
    'xm-uid': '2047'
}

letters_and_digits = string.ascii_letters + string.digits
def generate_random_string(length=16):
    return ''.join(random.choice(letters_and_digits) for _ in range(length))

def generate_random_phone():
    return "186"+''.join(random.choice(string.digits) for _ in range(8))

random_name=generate_random_string(5)

data = {
    'mname': f'唐鹏测试{random_name}',
    'mcontact': f'唐鹏测试{random_name}',
    'phone': generate_random_phone(),
    'invitecode': 'seeegj',
    'province': '广东',
    'city': '广州市',
    'area': '天河区',
    'address': '白云机场123',
    'houseNumber': '',
    'poiNote': '113.307392,23.387375',
    'size': '大客户',
    'type':'加盟店'
}

print(data)

response = requests.post(url, headers=headers, data=data)

if response.status_code == 200:
    print('Request was successful')
    print('Response:', response.json())
else:
    print(f'Failed to send request. Status code: {response.status_code}')
    print('Response:', response.text)

# %%
import pandas as pd

# df=pd.read_csv("./浙江门店安佳-2024.csv")
df = pd.read_excel("./全部门店安佳0620.xlsx", sheet_name="成都、苏州、上海、广东")
df.head(2)

# %%
# 获取token
import requests, os

login_url = "https://admin.summerfarm.net/authentication/auth/username/login"
login_data = {
    "username": "peng.tang@summerfarm.net",
    "password": os.getenv("XIANMU_ADMIN_PASSWORD"),
}

token = requests.post(login_url, data=login_data).json()

print(token)


headers = {
    "token": token.get("data").get("token"),
    "xm-rqid": "create_fake_merchant_tp",
    "xm-uid": "2047",
}

print(headers)

# %%
added_mid=set([457692,457693,457694,457695,457696,457697,457698,457699,457700,457701,457702,457703,457704,457705,457706,457707,457708,457709,457710,457711,457712,457713,457714,457715,457716,457717,457718,457719,457720,457721,457722,457723,457724,457725,457726,457727,457728,457729,457730,457731,457732,457733,457734,457735,457736,457737,457738,457739,457740,457741,457742,457743,457744,457745,457746,457747,457748,457749,457750,457751,457752,457753,457754,457755,457756,457757,457758,457759,457760,457761,457762,457763,457764,457765,457766,457767,457768,457769,457770,457771,457772,457773,457774,457775,457776,457777,457778,457779,457780,457781,457782,457783,457784,457785,457786,457787,457788,457789,457790,457791,457792,457793,457794,457795,457796,457809,457810,457811,457812,457813,457814,457815,457816,457817,457818,457819,457820,457821,457822,457823,457824,457825,457826,457827,457828,457829,457830,457831,457832,457833,457834,457835,457836,457837,457838,457839,457840,457841,457842,457843,457844,457845,457846,457847,457848,457849,457850,457851,457852,457853,457854,457855,457856,457857,457858,457859,457860,457861,457862,457863,457864,457865,457866,457867,457868,457869,457870,457871,457872,457873,457874,457875,457876,457877,457878,457879,457880,457881,457882,457883,457884,457885,457886,457887,457888,457889,457890,457891,457892,457893,457894,457895,457896,457897,457898,457899,457900,457901,457902,457903,457904,457905,457906,457907,457908,457909,457910,457911,457915,457916,457917,457918,457919,457920,457921,457922,457923,457924,457925,457926,457927,457928,457929,457930,457931,457932,457933,457934,457935,457936,457937,457938,457939,457940,457941,457942,457943,457944,457945,457946,457947,457948,457949,457950,457951,457952,457953,457954,457955,457956,457957,457958,457959,457960,457961,457962,457963,457964,457965,457966,457967,457968,457969,457970,457971,457972,457973,457974,457975,457976,457977,457978,457979,457980,457981,457982,457983,457984,457985,457986,457987,457988,457989,457990,457991,457992,457993,457994,457995,457996,457997,457998,457999,458000,458001,458002,458003,458004,458005,458006,458007,458008,458009,458010,458011,458012,458013,458015,458016,458017,458018,458019,458020,458021,458022,458023,458024,458025,458026,458027,458028,458029,458030,458031,458032,458033,458034,458035,458036,458037,458038,458039,458040,458041,458042,458043,458044,458045,458046,458047,458048,458049,458050,458051,458052,458053,458054,458055,458056,458057,458058,458059,458060,458061,458062])

# %%
def add_concat(row: pd.Series):
    # data = {
    #     "mId": 457535,
    #     "contact": "茶百道温州大象城",
    #     "phone": "12232123111",
    #     "province": "浙江",
    #     "city": "温州市",
    #     "area": "瓯海区",
    #     "address": "茶百道温州大象城",
    #     "contactAddressRemark": {"customRemark": "", "baseRemark": []},
    # }
    if int(row["mid"]) in added_mid:
        print(f"已经添加过了:{row['mid']}")
        return "added"
    url = "https://admin.summerfarm.net/merchant/addContact"
    direct = row["区"]
    if direct is None or "nan" == f"{direct}".lower():
        print(f"没有区县的城市:{row.to_dict()}")
        direct = row["市"]
    data = {
        "mId": row["mid"],
        "contact": row["客户名称"],
        "phone": f"{row['联系方式']}",
        "province": row["省"],
        "city": row["市"],
        "area": direct,
        "address": row["地址"],
        "contactAddressRemark": {
            "customRemark": f'服务区:{row["运营服务区"]}',
            "baseRemark": [],
        },
    }
    print(data)
    response = requests.post(url=url, json=data, headers=headers).json()
    print(response,"\n====")
    return response


df["addContactResult"] = df.apply(add_concat, axis=1)

df.head(2)

# %%
all_pending_review_contact=requests.get("https://admin.summerfarm.net/merchant/1/500?chat=1&pageIndex=1&pageSize=200&mId=", headers=headers).json()['data']['list']
all_pending_review_contact_df=pd.DataFrame(all_pending_review_contact)
all_pending_review_contact_df=all_pending_review_contact_df[all_pending_review_contact_df["adminId"]==1045263]
print(len(all_pending_review_contact_df), all_pending_review_contact_df.head(1)['contacts'].to_dict())
all_pending_review_contact_df.head(2)

# %%
all_pending_review_contact_df.to_csv("./全部门店安佳0620-待审核门店列表-东莞市.xlsx.csv", index=False)

# %%
def review_contact(row):
    url = f'https://admin.summerfarm.net/merchant/review/contact/{row["contactId"]}'

    data = {
        'status': '1',
        'poiNote': '113.753968,22.991181',
        'address': row['contacts'][0]['address'],
        'houseNumber': ''
    }

    response = requests.post(url, headers=headers, data=data).json()
    print(row['mname'], data['address'], response)
    return response

all_pending_review_contact_df['reviewResult']=all_pending_review_contact_df.apply(review_contact, axis=1)

all_pending_review_contact_df.head(2)[['phone','adminId','mname','contactId','areaName','reviewResult']]

# %%
len(all_pending_review_contact_df)

# %%
large_area_list=requests.get("https://admin.summerfarm.net/large-area/larges", headers=headers).json()['data']

# %%
area_list=[]
[area_list.extend(large_area['areaList']) for large_area in large_area_list]
print(area_list[0])
area_list_df=pd.DataFrame(area_list)
area_list_df.head(10)[['areaNo','areaName','administrativeArea','mapSection']]

# %%
# 修改门店运营服务区：
area_list_map = {}
for area in area_list:
    area_list_map[area["areaName"]] = {
        "areaName": area["areaName"],
        "areaNo": area["areaNo"],
    }

updated_mid = set(
    [
        457692,
        457693,
        457694,
        457695,
        457696,
        457697,
        457698,
        457699,
        457700,
        457701,
        457702,
        457703,
        457704,
        457705,
        457706,
        457707,
        457708,
        457709,
        457710,
        457711,
        457712,
        457713,
        457714,
        457715,
        457716,
        457717,
        457718,
        457719,
        457720,
        457721,
        457722,
        457723,
        457724,
        457725,
        457726,
        457727,
        457728,
        457729,
        457730,
        457731,
        457732,
        457733,
        457734,
        457735,
        457736,
        457737,
        457738,
        457739,
        457740,
        457741,
        457742,
        457743,
        457744,
        457745,
        457746,
        457747,
        457748,
        457749,
        457750,
        457751,
        457752,
        457753,
        457754,
        457755,
        457756,
        457757,
        457758,
        457759,
        457760,
        457761,
        457762,
        457763,
        457764,
        457765,
        457766,
        457767,
        457768,
        457769,
        457770,
        457771,
        457772,
        457773,
        457774,
        457775,
        457776,
        457777,
        457778,
        457779,
        457780,
        457781,
        457782,
        457783,
        457784,
        457785,
        457786,
        457787,
        457788,
        457789,
        457790,
        457791,
        457792,
        457793,
        457794,
        457795,
        457796,
        457809,
        457810,
        457811,
        457812,
        457813,
        457814,
        457815,
        457816,
        457817,
        457818,
        457819,
        457820,
        457821,
        457822,
        457823,
        457824,
        457825,
        457826,
        457827,
        457828,
        457829,
        457830,
        457831,
        457832,
        457833,
        457834,
        457835,
        457836,
        457837,
        457838,
        457839,
        457840,
        457841,
        457842,
        457843,
        457844,
        457845,
        457846,
        457847,
        457848,
        457849,
        457850,
        457851,
        457852,
        457853,
        457854,
        457855,
        457856,
        457857,
        457858,
        457859,
        457860,
        457861,
        457862,
        457863,
        457864,
        457865,
        457866,
        457867,
        457868,
        457869,
        457870,
        457871,
        457872,
        457873,
        457874,
        457875,
        457876,
        457877,
        457878,
        457879,
        457880,
        457881,
        457882,
        457883,
        457884,
        457885,
        457886,
        457887,
        457888,
        457889,
        457890,
        457891,
        457892,
        457893,
        457894,
        457895,
        457896,
        457897,
        457898,
        457899,
        457900,
        457901,
        457902,
        457903,
        457904,
        457905,
        457906,
        457907,
        457908,
        457909,
        457910,
        457911,
        457915,
        457916,
        457917,
        457918,
        457919,
        457920,
        457921,
        457922,
        457923,
        457924,
        457925,
        457926,
        457927,
        457928,
        457929,
        457930,
        457931,
        457932,
        457933,
        457934,
        457935,
        457936,
        457937,
        457938,
        457939,
        457940,
        457941,
        457942,
        457943,
        457944,
        457945,
        457946,
        457947,
        457948,
        457949,
        457950,
        457951,
        457952,
        457953,
        457954,
        457955,
    ]
)


for index, row in df.iterrows():
    m_id = row["mid"]
    if m_id in updated_mid:
        print(f"已经更新过了:{m_id}")
        continue
    # if index > 1:
    #     break
    put_area_no_url = f"https://admin.summerfarm.net/merchant/{m_id}"

    merchant_detail_url = (
        f"https://admin.summerfarm.net/sf-mall-manage/merchant/query/detail/{m_id}"
    )
    merchant_detail = requests.post(merchant_detail_url, headers=headers).json()["data"]

    real_area_name = ""
    try:
        real_area_name = merchant_detail["contacts"][
            len(merchant_detail["contacts"]) - 1
        ]["contactAddressRemark"]["customRemark"].split(":")[1]
    except Exception as e:
        print(f"获取服务区异常m_id:{m_id},", merchant_detail["contacts"])
        continue
    faked_area_no = merchant_detail["areaNo"]

    merchant_detail["areaName"] = area_list_map[real_area_name]["areaName"]
    merchant_detail["areaNo"] = area_list_map[real_area_name]["areaNo"]
    if "mcontact" not in merchant_detail:
        merchant_detail["mcontact"] = merchant_detail["mname"]
    if "poiNote" not in merchant_detail:
        merchant_detail["poiNote"] = "104.057969,30.540616"

    put_obj = {
        "address": merchant_detail.get("address"),
        "adminId": merchant_detail.get("adminId"),
        "area": merchant_detail.get("area"),
        "areaNo": merchant_detail.get("areaNo"),
        "city": merchant_detail.get("city"),
        "clueAddress": merchant_detail.get("clueAddress"),
        "clueMName": merchant_detail.get("clueMName"),
        "cluePhone": merchant_detail.get("cluePhone"),
        "cluePool": merchant_detail.get("cluePool"),
        "companyBrand": merchant_detail.get("companyBrand"),
        "contacts": merchant_detail.get("contacts"),
        "deliveryCar": merchant_detail.get("deliveryCar"),
        "direct": merchant_detail.get("direct"),
        "displayButton": merchant_detail.get("displayButton"),
        "doorPic": merchant_detail.get("doorPic"),
        "enterpriseScale": merchant_detail.get("enterpriseScale"),
        "esId": merchant_detail.get("esId"),
        "houseNumber": merchant_detail.get("houseNumber"),
        "mcontact": merchant_detail.get("mcontact"),
        "merchantType": merchant_detail.get("merchantType"),
        "mname": merchant_detail.get("mname"),
        "monthPurmoney": merchant_detail.get("monthPurmoney"),
        "outerMappings": merchant_detail.get("outerMappings"),
        "phone": merchant_detail.get("phone"),
        "poiNote": merchant_detail.get("poiNote"),
        "printOutTMSConfig": merchant_detail.get("printOutTMSConfig"),
        "province": merchant_detail.get("province"),
        "remark": merchant_detail.get("remark"),
        "server": merchant_detail.get("server"),
        "showPrice": merchant_detail.get("showPrice"),
        "size": merchant_detail.get("size"),
        "skuShow": merchant_detail.get("skuShow"),
        "type": merchant_detail.get("type"),
    }

    put_result = requests.put(put_area_no_url, json=put_obj, headers=headers).json()
    print({"m_id": m_id, "put_result": put_result}, f"\n{put_obj}", "\n<=====")
